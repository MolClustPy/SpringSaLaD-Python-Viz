# %%
from Visualization import *
import os
search_directory = os.path.join('Examples','Nephrin-Nck-NWasp','Final_version_test_SIMULATIONS', 'Simulation0_SIM_SIMULATIONS')

# %%
#Select a specific point in time

times = []
for i in range(1,251):
    times.append(i*2e-4)

Spatial_Analysis.plot(search_directory, [0.05])

# %%
Spatial_Analysis.time_course(search_directory, data_selection='rg', size_threshold=1)
# Out:
# Elapsed time: 0.1200 seconds
# Elapsed time: 0.1161 seconds
# Elapsed time: 0.1172 seconds
# Elapsed time: 0.1159 seconds
# Elapsed time: 0.1158 seconds
# Elapsed time: 0.1138 seconds
# Elapsed time: 0.1162 seconds
# Elapsed time: 0.1144 seconds
# Elapsed time: 0.1169 seconds
# Elapsed time: 0.1169 seconds
# Elapsed time: 0.1134 seconds
# Elapsed time: 0.1121 seconds
# Elapsed time: 0.1142 seconds
# Elapsed time: 0.1140 seconds
# Elapsed time: 0.1139 seconds
# Elapsed time: 0.1152 seconds
# Elapsed time: 0.1142 seconds
# Elapsed time: 0.1133 seconds
# Elapsed time: 0.1136 seconds
# Elapsed time: 0.1140 seconds
# Elapsed time: 0.1139 seconds
# Elapsed time: 0.1127 seconds
# Elapsed time: 0.1136 seconds
# Elapsed time: 0.1128 seconds
# Elapsed time: 0.1133 seconds
# Elapsed time: 0.1162 seconds
# Elapsed time: 0.1132 seconds
# Elapsed time: 0.1134 seconds
# Elapsed time: 0.1136 seconds
# Elapsed time: 0.1129 seconds
# Elapsed time: 0.1804 seconds
# Elapsed time: 0.1126 seconds
# ...

# %%
Spatial_Analysis.time_course(search_directory, data_selection='cs', size_threshold=1)

# %%
Spatial_Analysis.time_course(search_directory, data_selection='sd', indicies=[1], size_threshold=1)
