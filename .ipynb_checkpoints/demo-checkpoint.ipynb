# %%
import Plotter

# %%
path = 'Simulation0_SIM_AverageMoleculeCounts_0_23.csv'
#Plot data for a specific molecule
Plotter.stdevPlots(path, ['Adapter'])
#Plot data for a specific state
Plotter.stdevPlots(path, ['bound'])
#Plot specific columns with their indicies (the first column of data is 1)
Plotter.stdevPlots(path, [2,3,5])
#Use any combination of the above options
Plotter.stdevPlots(path, ['free', 3])
# Out:
# ['R']
# ['R', 'Adapter']
# Adapter
# ['R']
# ['R', 'Adapter']
# ['R']
# ['R', 'Adapter']
# ['R']
# ['R', 'Adapter']
# hi
