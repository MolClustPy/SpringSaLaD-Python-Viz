# %%
#model = 'output/Simulation0_SIM.txt'
model = '../Input_File_Editor/output.txt'

for i in range(5):
    command = f'langevin-windows-latest.exe simulate {model} {i}'
    # !{command}
# Out:
# Version = 1.3.2-0-g734c481
# in solver, running: 0
# This stdout file is associated with run counter 0.
# Simulation started.
# Simulation 1% complete. Elapsed time: 2.097 sec.
# Simulation 2% complete. Elapsed time: 4.152 sec.
# Simulation 3% complete. Elapsed time: 6.198 sec.
# Simulation 4% complete. Elapsed time: 8.236 sec.
# Simulation 5% complete. Elapsed time: 10.247 sec.
# Simulation 6% complete. Elapsed time: 12.268 sec.
# Simulation 7% complete. Elapsed time: 14.334 sec.
# Simulation 8% complete. Elapsed time: 16.424 sec.
# Simulation 9% complete. Elapsed time: 18.506 sec.
# Simulation 10% complete. Elapsed time: 20.623 sec.
# Simulation 11% complete. Elapsed time: 22.755 sec.
# Simulation 12% complete. Elapsed time: 24.841 sec.
# Simulation 13% complete. Elapsed time: 26.936 sec.
# Simulation 14% complete. Elapsed time: 29.061 sec.
# Simulation 15% complete. Elapsed time: 31.158 sec.
# Simulation 16% complete. Elapsed time: 33.295 sec.
# ...
