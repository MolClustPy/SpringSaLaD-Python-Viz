# %%
model = 'output/Simulation0_SIM.txt'

for i in range(5):
    command = f'langevin-windows-latest.exe simulate {model} {i}'
    # !{command}
# Out:
# Version = 1.3.2-0-g734c481
# in solver, running: 0
# This stdout file is associated with run counter 0.
# Simulation started.
# Simulation 1% complete. Elapsed time: 0.231 sec.
# Simulation 2% complete. Elapsed time: 0.444 sec.
# Simulation 3% complete. Elapsed time: 0.661 sec.
# Simulation 4% complete. Elapsed time: 0.878 sec.
# Simulation 5% complete. Elapsed time: 1.093 sec.
# Simulation 6% complete. Elapsed time: 1.308 sec.
# Simulation 7% complete. Elapsed time: 1.519 sec.
# Simulation 8% complete. Elapsed time: 1.730 sec.
# Simulation 9% complete. Elapsed time: 1.944 sec.
# Simulation 10% complete. Elapsed time: 2.154 sec.
# Simulation 11% complete. Elapsed time: 2.362 sec.
# Simulation 12% complete. Elapsed time: 2.583 sec.
# Simulation 13% complete. Elapsed time: 2.838 sec.
# Simulation 14% complete. Elapsed time: 3.085 sec.
# Simulation 15% complete. Elapsed time: 3.331 sec.
# Simulation 16% complete. Elapsed time: 3.550 sec.
# ...
