# %%
from Visualization.ClusterCrossLinking import *

# %%
vfile = r'Examples\Nephrin-Nck-NWasp\Final_version_test_SIMULATIONS\Simulation0_SIM_SIMULATIONS\Simulation0_SIM_FOLDER\viewer_files\Simulation0_SIM_VIEW_Run0.txt'
def plot(search_directory, times, hist=False):     
    txtfile = r"Examples\Nephrin-Nck-NWasp\Final_version_test_SIMULATIONS\Simulation0_SIM_SIMULATIONS\Simulation0_SIM_FOLDER\Simulation0_SIM.txt"
    vf = r'Examples\Nephrin-Nck-NWasp\Final_version_test_SIMULATIONS\Simulation0_SIM_SIMULATIONS\Simulation0_SIM_FOLDER\viewer_files\Simulation0_SIM_VIEW_Run2.txt'

    #txtfile = data_file_finder(search_directory, [], search_term='.txt')
    #vf = data_file_finder(search_directory, ['viewer_files'], run = 0)

    #ss_tps = np.arange(0.02, 0.05+0.01, 0.01)
    ss_tps = [0.02]

    #AS = ["PRM", "SH3_1", "SH3_2","SH3_3","SH2","pTyr_1_2", "pTyr_3"]  # active sites

    #AS = ['sh3', 'prm']
    #AS = ['SH3', 'PRM', ]

    CLI = CrossLinkIndex(txtfile, ss_timeSeries=ss_tps)

    #title_str = times_2_title(times)

    print(CLI)
    #d = cl.mapSiteToMolecule()
    #rif = ReadInputFile(txtfile)
    #print(rif.getReactiveSites())
    #print(len(cl.getActiveSiteIDs())) 
    CLI.getRadialDist(vf)
    #CLI.getSI(vf) 
    #CLI.getSI_stat() 
    #CLI.plot_SI_stat(color='k', fs=16, xticks=None, yticks=None, hist=hist, title_str=title_str)
    #CLI.plot_SI_stat(color='c', xticks=None, yticks=None)

# %%
plot('a', 'b', 'c')
# Out:
# Class : CrossLinkIndex
# System : Examples\Nephrin-Nck-NWasp\Final_version_test_SIMULATIONS\Simulation0_SIM_SIMULATIONS\Simulation0_SIM_FOLDER\Simulation0_SIM.txt
# Active siteList based on rxnrules ...
# ['SH3_1', 'SH2', 'SH3_3', 'PRM', 'SH3_2', 'pTyr_3', 'pTyr_1_2']
# ['SCENE\n', 'SceneNumber\t100\tCurrentTime\t0.020000000000648145\n', 'ID\t100000011\t2.0\tORANGE\t-44.711799\t12.246482\t49.989991\n', 'ID\t100000002\t1.0\tGREEN\t-33.939930\t14.523813\t51.815565\n', 'ID\t100000005\t1.0\tPINK\t-29.646154\t12.694272\t59.794224\n', 'ID\t100000010\t1.0\tGREEN\t-27.511068\t5.172229\t64.590706\n', 'ID\t100000013\t1.6\tORANGE\t-38.718173\t11.699865\t53.151518\n', 'ID\t100000006\t1.0\tGREEN\t-28.042947\t11.314772\t62.709783\n', 'ID\t100000009\t1.0\tPINK\t-30.308326\t7.240443\t64.203234\n', 'ID\t100000004\t1.0\tGREEN\t-30.035430\t11.137806\t56.594356\n', 'ID\t100000007\t1.0\tPINK\t-25.890394\t9.149160\t64.611929\n', 'ID\t100000012\t2.25\tORANGE\t-26.836223\t3.897291\t69.376355\n', 'ID\t100000003\t1.0\tPINK\t-32.174095\t12.343740\t54.014832\n', 'ID\t100000001\t1.0\tPINK\t-32.915388\t12.373852\t49.276276\n', 'ID\t100000000\t1.0\tGREEN\t-36.031609\t13.313581\t50.619023\n', 'ID\t100000014\t1.0\tPINK\t-41.334442\t10.859006\t51.640021\n', 'ID\t100000008\t1.0\tGREEN\t-27.520029\t7.398852\t62.109827\n', 'ID\t100000015\t1.0\tPINK\t-39.727852\t8.290485\t51.431423\n', 'ID\t100010003\t1.0\tPINK\t7.573613\t2.307131\t85.145944\n', 'ID\t100010002\t1.0\tGREEN\t7.105213\t0.818839\t82.098021\n', 'ID