# %%
from Visualization.Average_z_pos import plot
import os

#Create the relative path to your desired SIMULATIONS or FOLDER directory
search_directory = os.path.join('Examples','Nephrin-Nck-NWasp','Final_version_test_SIMULATIONS', 'Simulation0_SIM_SIMULATIONS')

# %%
#TODO: stdev ontop of averages
#Show the average Z position of each type of site (all corresponding to the same color)
plot(search_directory, indicies=[], verbose=True, legend_right=True, list_sites=False)
